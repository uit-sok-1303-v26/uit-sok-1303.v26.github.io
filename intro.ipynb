# %% [markdown]
# # SOK-1303 Mikroøkonomi
#
# ![Bilde](image-1.png)

# %% [markdown]
# ## Velkommen til dette kurset i Mikroøkonomi!
#
# Kurset skal gi en grunnleggende forståelse av hvordan individer og bedrifter tar beslutninger, hvordan markeder fungerer, og hvordan ressurser fordeles i samfunnet.
#
# ## Pensum
#
# I dette kurset bruker vi læreboken Mikroøkonomi – en ABC på 1-2-3 av Kjetil Bjorvatn (2. utgave) samt den tilhørende oppgaveboken Mikroøkonomi – en ABC på 1-2-3: Oppgaver, tips og løsningsforslag av samme forfatter. Pensum for kurset inkluderer kapittel 1–11.
#
# ## Informasjon om undervisningen i kurset
#
# Undervisningen i dette kurset består av følgende aktiviteter:
#
# - **Forelesninger:**
# - **Seminarer:** med fokus på casearbeid, der Python benyttes for å løse oppgaver.
# - **Veiledning av arbeidskrav**
# - **Videoforelesninger**
#
# ## Seminarer
#
# I dette faget er det lagt opp til seminarundervisning etter at forelesningene er gjennomført. På seminarene vil **Python-koder**, som er lagt ut i Jupyter-notatblokker, bli gjennomgått. I tillegg vil seminarene dekke anbefalte seminaroppgaver som dere finner under modulene. Det vil også bli gitt veiledning i koding knuttet til arbeidskravet.

# %% [markdown]
# ## **Nedlastning av Python og Visual Studio Code**
#
# ## 1. Installere Python
#
# ### **Windows:**
#
# På noen systemer er det tilstrekkelig at du skriver `python` i kommandovinduet. Om ikke det fungerer, gjør slik:
#
# 1. Gå til [installasjonssiden](https://www.python.org/downloads/) og last ned
# 4. Installer for alle brukere (krever admin login) og **hak av for å legge til "PATH"**.
#
# Hvis det ikke er en boks for "Add Python to PATH", så kan du prøve å lukke installasjonen og heller høyreklikke på filen og "Kjør som administrator"
#
# ### **Mac:**
#
# Gå til [https://www.python.org/downloads/](https://www.python.org/downloads/).
#
# Last ned nyeste versjon til MacOS.
#
# ### Tips:
# Last ned nyeste versjon av Python til PC/Mac'en deres.
#
# ## 2. Installere Visual Studio Code
# I dette kurset er seminarene lagt opp til at skal vi jobbe med Jupyter Notebooks, og da er [Visual Studio Code](https://code.visualstudio.com/) et glimrende verktøy.
#
# Denne kan også være lurt å kjøre som administrator siden denne også kan be om "add to path".
#
# Dere finner nedlastning for både Mac og Windows på nettsiden [her](https://code.visualstudio.com/)!
#
# ## 3. Åpne Visual Studio Code
# Visual Studio Code, forkortes ofte bare til VSCode.
#
# Når dere har lastet ned programmet, gjør følgende:
# - Åpne programmet og finn **Extensions** på venstresiden av applikasjonen.
# - Her skal dere finne **Jupyter** og trykk "*Install*".
# - Deretter finner dere **Python** (også i **Extensions**) og trykker "*Install*".
#
# ## ```pip``` - og hvorfor det er viktig!
# For å laste ned pakker så vil vi bruke kommandoen ```%pip install XXX``` eller ```!pip install XXX``` hvor ```XXX``` er et bibliotek. Bibliotek brukes mye i Python, og kan sees på som pakker man henter ut, for å gjøre spesifikke kommandoer.
#
# For å kunne kjøre ```!pip install``` eller ```!pip install``` trenger dere å laste ned ```!pip``` på PC/Mac'en deres.
#
# Ved å laste ned kapitellene på kurssiden så ligger koden allerede inne, eller så kan du lage en ny jupyter notatblokk og kopiere inn koden i de neste kodeblokkene under her

# %%
import sys
# !{sys.executable} -m ensurepip --upgrade
# %pip install --upgrade pip
# %pip install numpy
